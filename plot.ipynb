# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Recreate the DataFrame from the initial analysis
data = {
    'Qubit': [4, 5, 6, 7],
    'GA-QSVM': [91.5, 93.2, 94.2, 92.6],
    'Z-Feature': [75.5, 77.0, 76.7, 77.5],
    'ZZ-feature': [69.4, np.nan, np.nan, np.nan],
    'RBF': [94.5, 95.2, 94.7, 95.0]
}
df = pd.DataFrame(data)
df = df.set_index('Qubit')

# Set a more visually appealing style from seaborn
sns.set_theme(style="whitegrid")

# Create the plot
plt.figure(figsize=(12, 7))
ax = sns.lineplot(data=df, marker='o', linewidth=2.5, markersize=8, dashes=False)

# Improve title and labels
plt.title('Accuracy Evolution on Breast Cancer Dataset', fontsize=16)
plt.xlabel('Number of Qubits', fontsize=12)
plt.ylabel('Accuracy (%)', fontsize=12)
plt.xticks(df.index, fontsize=10)
plt.yticks(fontsize=10)
plt.legend(title='Algorithm', fontsize=10)

# Show the plot
plt.show()

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Create the DataFrame based on the new image (input_file_0.png)
data_new = {
    'Qubit': [4, 5, 6, 7],
    'GA-QSVM': [76.5, 79.1, 83.1, 84.5],
    'Z-Feature': [54.7, 58.3, 63.5, 67.0],
    'ZZ-feature': [15.7, np.nan, np.nan, np.nan],
    'RBF': [78.3, 82.6, 84.7, 87.3]
}
df_new = pd.DataFrame(data_new)
df_new = df_new.set_index('Qubit')

# Set a visually appealing style from seaborn
sns.set_theme(style="whitegrid")

# Create the plot
plt.figure(figsize=(12, 7))
ax = sns.lineplot(data=df_new, marker='o', linewidth=2.5, markersize=8, dashes=False)

# Add title and labels
plt.title('Accuracy Evolution on Digits Dataset', fontsize=16)
plt.xlabel('Number of Qubits', fontsize=12)
plt.ylabel('Accuracy (%)', fontsize=12)
plt.xticks(df_new.index, fontsize=10)
plt.yticks(fontsize=10)
plt.legend(title='Algorithm', fontsize=10)

# Show the plot
plt.show()

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Create the DataFrame based on the new image (input_file_0.png)
# The rule is to take the last number from any cell with a '-' separator.
data_final = {
    'Qubit': [4, 5, 6, 7],
    'GA-QSVM': [96.41, 97.05, 97.44, 97.43],
    'Z-Feature': [90.51, 90.51, 90.9, 91.15],
    'ZZ-feature': [73.85, np.nan, np.nan, np.nan],
    'RBF': [96.54, 96.41, 97.18, 97.69]
}
df_final = pd.DataFrame(data_final)
df_final = df_final.set_index('Qubit')

# Set a visually appealing style from seaborn
sns.set_theme(style="whitegrid")

# Create the plot
plt.figure(figsize=(12, 7))
ax = sns.lineplot(data=df_final, marker='o', linewidth=2.5, markersize=8, dashes=False)

# Add title and labels
plt.title('Accuracy Evolution on Wine Dataset', fontsize=16)
plt.xlabel('Number of Qubits', fontsize=12)
plt.ylabel('Accuracy (%)', fontsize=12)
plt.xticks(df_final.index, fontsize=10)
plt.yticks(fontsize=10)
plt.legend(title='Algorithm', fontsize=10)

# Show the plot
plt.show()
